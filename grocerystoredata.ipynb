# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
tj_filepath = "DataFiles/traderjoes.csv"
wf_filepath = "DataFiles/wholefoods.csv"

# %%
tj_data = pd.read_csv(tj_filepath)
wf_data = pd.read_csv(wf_filepath)

# %%
# ####Whole Foods Data Transformation

# %%
wf_data[["street", "city", "state", "zip", "none"]] = wf_data["address"].str.split(",", expand=True)
wf_data
# Out:
#            long        lat                name  \
# 0    -86.589911  34.712156          Huntsville
# 1    -88.150973  30.677104              Mobile
# 2    -86.752324  33.460088      Mountain Brook
# 3    -86.172682  32.358596          Montgomery
# 4    -94.146200  36.113600        Fayetteville
# ..          ...        ...                 ...
# 500 -122.461261  48.743633  Bellingham Lakeway
# 501  -89.444164  43.074879             Madison
# 502  -88.051510  43.075442           Wauwatosa
# 503  -87.883762  43.060324           Milwaukee
# 504 -110.794090  43.463666     Jackson Wyoming
#
#                                              address  \
# 0        2501 Memorial Pkwy SW, Huntsville, AL 35801
# 1                3968 Airport Blvd, Mobile, AL 36608
# 2    3100 Cahaba Village Plaza, Birmingham, AL 35243
# 3               1450 Taylor Rd, Montgomery, AL 36117
# 4         3425 N College Ave, Fayetteville, AR 72703
# ..                                               ...
# 500            1030 Lakeway Dr, Bellingham, WA 98229
# 501           3313 University Ave, Madison, WI 53705
# 502         11100 W Burleigh St, Wauwatosa, WI 53222
# 503         2305 N Prospect Ave, Milwaukee, WI 53211
# 504             1155 S Highway 89, Jackson, WY 83001
#
#                         street           city      state   zip  none
# 0        2501 Memorial Pkwy SW     Huntsville   AL 35801  None  None
# 1            3968 Airport Blvd         Mobile   AL 36608  None  None
# 2    3100 Cahaba Village Plaza     Birmingham   AL 35243  None  None
# 3               1450 Taylor Rd     Montgomery   AL 36117  None  None
# 4           3425 N College Ave   Fayetteville   AR 72703  None  None
# ..                         ...            ...        ...   ...   ...
# 500            1030 Lakeway Dr     Bellingham   WA 98229  None  None
# 501        3313 University Ave        Madison   WI 53705  None  None
# 502        11100 W Burleigh St      Wauwatosa   WI 53222  None  None
# 503        2305 N Prospect Ave      Milwaukee   WI 53211  None  None
# 504          1155 S Highway 89        Jackson   WY 83001  None  None
#
# [505 rows x 9 columns]

# %%
wf_data = wf_data.drop(columns=["long", "lat", "none", "address", "zip"])
wf_data
# Out:
#                    name                     street           city      state
# 0            Huntsville      2501 Memorial Pkwy SW     Huntsville   AL 35801
# 1                Mobile          3968 Airport Blvd         Mobile   AL 36608
# 2        Mountain Brook  3100 Cahaba Village Plaza     Birmingham   AL 35243
# 3            Montgomery             1450 Taylor Rd     Montgomery   AL 36117
# 4          Fayetteville         3425 N College Ave   Fayetteville   AR 72703
# ..                  ...                        ...            ...        ...
# 500  Bellingham Lakeway            1030 Lakeway Dr     Bellingham   WA 98229
# 501             Madison        3313 University Ave        Madison   WI 53705
# 502           Wauwatosa        11100 W Burleigh St      Wauwatosa   WI 53222
# 503           Milwaukee        2305 N Prospect Ave      Milwaukee   WI 53211
# 504     Jackson Wyoming          1155 S Highway 89        Jackson   WY 83001
#
# [505 rows x 4 columns]

# %%
temp_df = wf_data["state"].str.split(expand=True)
temp_df
# Out:
#       0      1     2
# 0    AL  35801  None
# 1    AL  36608  None
# 2    AL  35243  None
# 3    AL  36117  None
# 4    AR  72703  None
# ..   ..    ...   ...
# 500  WA  98229  None
# 501  WI  53705  None
# 502  WI  53222  None
# 503  WI  53211  None
# 504  WY  83001  None
#
# [505 rows x 3 columns]

# %%
wf_data = wf_data.assign(state=temp_df[0], zip=temp_df[1])
wf_data
# Out:
#                    name                     street           city state    zip
# 0            Huntsville      2501 Memorial Pkwy SW     Huntsville    AL  35801
# 1                Mobile          3968 Airport Blvd         Mobile    AL  36608
# 2        Mountain Brook  3100 Cahaba Village Plaza     Birmingham    AL  35243
# 3            Montgomery             1450 Taylor Rd     Montgomery    AL  36117
# 4          Fayetteville         3425 N College Ave   Fayetteville    AR  72703
# ..                  ...                        ...            ...   ...    ...
# 500  Bellingham Lakeway            1030 Lakeway Dr     Bellingham    WA  98229
# 501             Madison        3313 University Ave        Madison    WI  53705
# 502           Wauwatosa        11100 W Burleigh St      Wauwatosa    WI  53222
# 503           Milwaukee        2305 N Prospect Ave      Milwaukee    WI  53211
# 504     Jackson Wyoming          1155 S Highway 89        Jackson    WY  83001
#
# [505 rows x 5 columns]

# %%
# #### Trader Joe's Transformation

# %%
tj_data= tj_data.drop(columns=["landline", "mobile", "website"])
tj_data
# Out:
#                                     store_name                   street  \
# 0       Trader Joe's Rancho Palos Verdes (233)     31176 Hawthorne Blvd
# 1                 Trader Joe's Charlotte (744)    1133 Metropolitan Ave
# 2                  Trader Joe's Sunnyvale (68)  316 West El Camino Real
# 3                    Trader Joe's Corona (213)            2790 Cabot Dr
# 4                Trader Joe's El Cerrito (108)     225 El Cerrito Plaza
# ..                                         ...                      ...
# 516  Trader Joe's Chicago - Lincoln Park (691)      1840 N Clybourn Ave
# 517                  Trader Joe's Concord (83)         785 Oak Grove Rd
# 518  Trader Joe's San Diego - Point Loma (188)          2401 Truxtun Rd
# 519           Trader Joe's Sandy Springs (731)     6277 Roswell Road NE
# 520               Trader Joe's Scarsdale (531)      727 White Plains Rd
#
#                     city state    zip
# 0    Rancho Palos Verdes    CA  90275
# 1              Charlotte    NC  28204
# 2              Sunnyvale    CA  94087
# 3                 Corona    CA  92883
# 4             El Cerrito    CA  94530
# ..                   ...   ...    ...
# 516              Chicago    IL  60614
# 517              Concord    CA  94518
# 518            San Diego    CA  92106
# 519        Sandy Springs    GA  30328
# 520            Scarsdale    NY  10583
#
# [521 rows x 5 columns]

# %%
tj_data= tj_data.rename(columns={"store_name": "name"})
tj_data
# Out:
#                                           name                   street  \
# 0       Trader Joe's Rancho Palos Verdes (233)     31176 Hawthorne Blvd
# 1                 Trader Joe's Charlotte (744)    1133 Metropolitan Ave
# 2                  Trader Joe's Sunnyvale (68)  316 West El Camino Real
# 3                    Trader Joe's Corona (213)            2790 Cabot Dr
# 4                Trader Joe's El Cerrito (108)     225 El Cerrito Plaza
# ..                                         ...                      ...
# 516  Trader Joe's Chicago - Lincoln Park (691)      1840 N Clybourn Ave
# 517                  Trader Joe's Concord (83)         785 Oak Grove Rd
# 518  Trader Joe's San Diego - Point Loma (188)          2401 Truxtun Rd
# 519           Trader Joe's Sandy Springs (731)     6277 Roswell Road NE
# 520               Trader Joe's Scarsdale (531)      727 White Plains Rd
#
#                     city state    zip
# 0    Rancho Palos Verdes    CA  90275
# 1              Charlotte    NC  28204
# 2              Sunnyvale    CA  94087
# 3                 Corona    CA  92883
# 4             El Cerrito    CA  94530
# ..                   ...   ...    ...
# 516              Chicago    IL  60614
# 517              Concord    CA  94518
# 518            San Diego    CA  92106
# 519        Sandy Springs    GA  30328
# 520            Scarsdale    NY  10583
#
# [521 rows x 5 columns]

# %%
connection_string = "postgres:postgres@localhost:5432/grocery_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# <ipython-input-15-2d97e9123e98>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# <string> in table_names(self, schema, connection)
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    3109         :param connection: Optional, use a specified connection.
#    3110         """
# -> 3111         with self._optional_conn_ctx_manager(connection) as conn:
#    3112             insp = inspection.inspect(conn)
#    3113             return insp.get_table_names(schema)
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2857     def _optional_conn_ctx_manager(self, connection=None):
#    2858         if connection is None:
# -> 2859             with self.connect() as conn:
#    2860                 yield conn
#    2861         else:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
# -> 3144                 Connection._handle_dbapi_exception_noconnection(
#    3145                     e, dialect, self
#    3146                 )
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# /opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
